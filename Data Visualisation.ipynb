# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('instahyre_data.csv')
df
# Out:
#                                                   Name  \
# 0       Autonomize AI - Lead Machine Learning Engineer
# 1                                 Autonomize AI - SDET
# 2                  Crackle Technologies - Web Engineer
# 3                         D. E. Shaw - Project Manager
# 4                               Foxtale - Data Analyst
# ..                                                 ...
# 295               Rapyuta Robotics - Software Engineer
# 296  SambaNova Systems - Senior Site Reliability En...
# 297                                ShareChat - SDE - 2
# 298               ShyftLabs - Senior Backend Developer
# 299                  SwitchOn - QA Automation Engineer
#
#                                 Location  Founded  Employees  \
# 0             Job available in Bangalore     2021       30.0
# 1             Job available in Bangalore     2021       30.0
# 2                 Job available in Delhi     2023        5.0
# ...

# %% [markdown]
# Histogram of Founded Year

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Founded'].dropna(), bins=20, kde=True)
plt.title('Distribution of Founded Year')
plt.xlabel('Founded Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Box Plot on Employee count.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Employees', y='Location', data=df)
plt.title('Box Plot of Employee Count by Location')
plt.xlabel('Number of Employees')
plt.ylabel('Location')
plt.show()

# %% [markdown]
# Pair Plot of Founded Year and Employee Count

# %%
sns.pairplot(df[['Founded', 'Employees']])
plt.title('Pair Plot of Founded Year and Employee Count')
plt.show()

# %% [markdown]
# Heatmap of correlation matrix

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-12-f96464a2691e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# Word Cloud of Skills

# %%
from wordcloud import WordCloud

skills_text = ' '.join(df['Skills'].explode().dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(skills_text)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Bar Chart of Job Distribution by Location

# %%
plt.figure(figsize=(12, 6))
location_counts = df['Location'].value_counts().head(10)
location_counts.plot(kind='bar', color='skyblue')
plt.title('Top 10 Job Locations')
plt.xlabel('Location')
plt.ylabel('Number of Jobs')
plt.show()

# %% [markdown]
# Bar Chart of top 10 Mentioned Skills

# %%
plt.figure(figsize=(12, 6))
top_skills = df['Skills'].explode().value_counts().head(10)
top_skills.plot(kind='bar', color='green')
plt.title('Top 10 Most Mentioned Skills')
plt.xlabel('Skill')
plt.ylabel('Number of Mentions')
plt.show()

# %% [markdown]
# Scatter Plot : Founded Vs Employees

# %%
plt.scatter(df['Founded'], df['Employees'], color='skyblue', alpha=0.5)
plt.title('Scatter Plot: Founded vs Employees')
plt.xlabel('Founded Year')
plt.ylabel('Number of Employees')
plt.show()
